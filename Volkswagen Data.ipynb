# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1,29,29)
tweet_freq = [106, 67, 97, 78,71,76,89, 79,70,69,85,91,83,96,225,200,137,663,1688,1759,1147,785,345,267,369,
              380,323,230,222]
plt.plot(x, tweet_freq)
plt.title('Volume')
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
tweet_fav = [51,59,79,49,35,65,41,18,51,38,30,35,68,41,107,53,81,516,2149,1444,881,1361,453,1280,584,
1164,179,598,115]
tweet_retweets = [12,16,12,45,6,15,4,14,9,3,5,7,9,4,31,24,55,176,1716,1225,498,793,159,511,185,901,112,213,
31]

# %%
plt.plot(x, tweet_fav)
plt.title('Favorites')
# Out:
# Text(0.5, 1.0, 'Favorites')

# %%
plt.plot(x, tweet_retweets)
plt.title('Retweets')
# Out:
# Text(0.5, 1.0, 'Retweets')

# %%
plt.plot(x, tweet_freq, label='Volume')
plt.plot(x, tweet_fav, label='Favorites')
plt.plot(x, tweet_retweets,label='Retweets')
plt.title('Volume,Favorites, and Retweets')
plt.legend()

# %%
from pandas import read_csv
from matplotlib import pyplot
import pandas as pd
series = read_csv('volkswagen_cleaned_tweets.csv', header=0, index_col=0)
data = pd.read_csv('volkswagen_cleaned_tweets.csv', index_col=0, parse_dates=True)
#pyplot.plot(series.date, series.favorites)
#series.plot()
#pyplot.show()
#fav_int = series.favorites.astype(int)

df1 = pd.DataFrame(series, columns=['date'])
df2 = pd.DataFrame(series, columns=['favorites'])
#plt.plot(df1, df2)
#matplotlib.pyplot.plot(df2.index, df2.events)
#matplotlib.pyplot.show()
