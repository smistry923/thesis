# %% [markdown]
# ## Fetching Tweets

# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 
import pandas as pd
  
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
        # keys and tokens from the Twitter Dev Console 
        consumer_key = 'X'
        consumer_secret = 'X'
        access_token = 'X'
        access_token_secret = 'X'
      
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count, lang='en') 
            #fetched_tweets.to_csv('Users⁩/⁨suchita⁩/⁨Documents/Tweets.csv'⁩)
            #print(fetched_tweets)
            
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                # saving favorites of tweet
            
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
  
def main(query_string): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = query_string, count = 10)
     
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text'])

# %% [markdown]
# ### Apple

# %%
if __name__ == "__main__": 
    # calling main function 
    main(['iPhone'])
    main(['iPad'])
    main(['iMac'])
    main(['Macbook'])
# Out:
# Positive tweets percentage: 33.333333333333336 %
# Negative tweets percentage: 22.22222222222222 %
# Neutral tweets percentage: 44.44444444444444 %
#
#
# Positive tweets:
# RT @hyeNuha: How long does a minimum wage worker has to work to buy a new iPhone 12 Pro Max 512GB?
#
# UK: 21 days
# Germany: 21 days
# Japan: 21…
# RT @MikeSievert: I have very cool #iPhone12 news for long-time customers (5+ years) on @TMobile AND @Sprint. When you trade in to upgrade,…
# @holyheckitsadub To be sure, are you casting it from a certain app (e.g. Spotify podcast, Podcast Go)? If not, are… https://t.co/S44JqubSba
#
#
# Negative tweets:
# I’ve just spent way too long trying to get Google on my iPhone to let me try the new hum a song feature.
#
# Google k… https://t.co/2NBxUG7IZA
# i think imma wait for the iPhone 13 cuz fuck 12
# Positive tweets percentage: 25.0 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 75.0 %
#
#
# Positive tweets:
# Rich kid had dozens of iPad and laptops
#
# Forgot all about it
#
# Kinda funny https://t.co/rM8PvHX2MQ
# @Bakari_Sellers Watching @JoeBiden on my 75in TV, watching tRump on my iPad lol
#
#
# Negative tweets:
# Positive tweets percentage: 60.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 30.0 %
#
#
# Positive tweets:
# For what it’s worth...there’s a cool photo below. But also, $imac and $trch are on #ssr tomorrow as is $ncty but th… https://t.co/tOufBPCHZu
# @nappyisCRACKED iMac tower inspires me to build my own
# haha im tweeting this from a 20" imac g4
# RT @thewealthdad: Most drive to work in their car $F, pick up their favorite coffee $SBUX, login to their computer operated by $MSFT, searc…
# RT @1BreannaNichole: If you genuinely have a good heart , protect that shit .
# RT @goldlakerss: All these Laker role players the media said are trash suddenly getting interest from so many teams. Funny
#
#
# Negative tweets:
# @chiakokhua @TUM_APISAK @davideneco25320 @davidbepo @Apple well, this gb results were really unexpected, at least f… https://t.co/oAOCVwef6X
# Positive tweets percentage: 25.0 %
# Negative tweets percentage: 50.0 %
# Neutral tweets percentage: 25.0 %
#
#
# Positive tweets:
# RT @dantoujours: So just so I follow this story:
#
# Hunter Biden, who lives in Los Angeles, decides to fly 3000 miles across country, to drop…
#
#
# Negative tweets:
# This is disgustinggggggg and he gotta MACBOOK you filthy whore 🤮🤮 https://t.co/3kYYuMJ19A
# Sitting in a mediocre, somewhat rundown apartment surrounded my retro computer stuff, string on a futon with a MacB… https://t.co/pA7DeJuYno

# %% [markdown]
# ### Google

# %%
if __name__ == "__main__": 
    # calling main function 
    main(['Google Home'])
    main(['Chromebook'])
    main(['Google Drive'])
    main(['Google Docs'])
    main(['GOOGL'])
# Out:
# Positive tweets percentage: 50.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 40.0 %
#
#
# Positive tweets:
# Google Nest Secure Alarm System Starter Pack itemprop= name Google Nest Secure Alarm System Starter Pack https://t.co/LD1BLF9tfU
# RT @EducPlus: Check out our High Impact Instructional Strategies #PD series. Learn more &amp; register here: https://t.co/HpzISGCqiC #EdPlus #V…
# RT @jasontries: Hey #tdsb! New Lunch + Learn sessions! 📅Save the date!  Quick, bite-sized learning done in 20 minutes! Join us for one of t…
# RT @JimFruchterman: I just had a great conversation with Antonio Aguilera about #socent, and I didn't know this/his back story on the tech…
# Top 5 Standing Desks for Home Use https://t.co/ynuAsR5HKO https://t.co/iQLAjnvVYQ
#
#
# Negative tweets:
# Go big or go home (or in this case go to jail) #CPA #TaxCrooks #TaxFraud #IRS
# https://t.co/uZfUnkIVyr
# Positive tweets percentage: 40.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 50.0 %
#
#
# Positive tweets:
# RT @ADANational: Good news for Chrome users! @Google has announced new accessibility options for their Chromebooks, as well as updates to t…
# RT @FISD_Wildcats: Chromebooks are available for all students in Fabens ISD. If you did not pick up a Chromebook from your child's campus,…
# RT @TeamMoneyMoon1: Congrats to Solomon’s Superstar winner, Karen Koch, from September’s wireless contest. Enjoy that Chromebook!!! @solomo…
# hello from my chromebook its very pretty but also it comes with 3 months of stadia pro so thats been happening
#
#
# Negative tweets:
# Parents and students, please follow the directions below to properly shut down and update your chromebook. This wil… https://t.co/8DXR0JnSRB
# Positive tweets percentage: 0.0 %
# Negative tweets percentage: 11.11111111111111 %
# Neutral tweets percentage: 88.88888888888889 %
#
#
# Positive tweets:
#
#
# Negative tweets:
# RT @nct_92: [RAW] 201015 #NCT WORLD 2.0 EP01
#
# 📌https://t.co/BSveh5HdP9 https://t.co/NVFuhyfCYZ
# Positive tweets percentage: 30.0 %
# Negative tweets percentage: 20.0 %
# Neutral tweets percentage: 50.0 %
#
#
# Positive tweets:
# RT @_whitneywebb: NEW at @TLAVagabond
#
# According to official docs and the head of Op Warp Speed, every American who gets the Warp Speed Co…
# RT @luxapartment_: New Luxury Apartment at Sec 13 Shah Alam 😍
#
# The cheapest project at the centre of Shah Alam!
#
# Gaji selepas komitmen RM1…
# RT @Joocheekiess: MONSTA X FATAL LOVE SPAIN AND EU GO!
#
# I’ll be making a spanish and europe go for the new albums through ktown4u!
#
# all alb…
#
#
# Negative tweets:
# It's not too late to sign up for an audition time for our Devised Mental Health Show! Auditions are tomorrow from 7… https://t.co/YxGTHQXNhn
# RT @AnnyeongMeron: TWICE EYES WIDE OPEN 🇵🇭 PH GO (REPRICED)
# ❤ We accept 50%DP ❤
# ❤ With a lot of freebies from us! ❤
# ⬜️ DOO: Until supplies…
# Positive tweets percentage: 33.333333333333336 %
# Negative tweets percentage: 33.333333333333336 %
# Neutral tweets percentage: 33.333333333333336 %
#
#
# Positive tweets:
# RT @thewealthdad: Most drive to work in their car $F, pick up their favorite coffee $SBUX, login to their computer operated by $MSFT, searc…
#
#
# Negative tweets:
# Bill Gates Says Tech Giants Should Be Probed Separately If Regulators 'Want To Get Serious' About Antitrust Concern… https://t.co/27xPhe2MZu

# %% [markdown]
# ### Tesla

# %%
if __name__ == "__main__": 
    # calling main function 
    main(['Tesla'])
    main(['tesla'])
    main(['TSLA'])
    main(['Model 3'])
    main(['Model x'])
    main(['Model y'])
    main(['Model s'])
    main(['model 3'])
    main(['model x'])
    main(['model y'])
    main(['model s'])
# Out:
# Positive tweets percentage: 40.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 50.0 %
#
#
# Positive tweets:
# RT @danhadzami: My daughter’s favorite feature.
#
# @elonmusk @Tesla https://t.co/WLHY3x9tZt
# @OGRedd I'm no fan of Morrey or The Rockets,  or FurTURDada but he was right about the ChiComs.
#
# Also, Tesla needs… https://t.co/DFQGLDsoxq
# RT @CanYamanMalta_: I miss Tesla so much too 🤧❤
# #NetflixBayYanlış
# #BayYanlışOnLine https://t.co/9uc9dykbt6
# When Tesla went crazy with photography and graphic design. Love it, lol.
#
# https://t.co/5HCqr04656
#
#
# Negative tweets:
# RT @Auto_Porn: Retweet if you'd whip a matte black Tesla Cybertruck
# cc: @elonmusk https://t.co/lhQZ2sMvsU
# Positive tweets percentage: 40.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 50.0 %
#
#
# Positive tweets:
# RT @danhadzami: My daughter’s favorite feature.
#
# @elonmusk @Tesla https://t.co/WLHY3x9tZt
# @OGRedd I'm no fan of Morrey or The Rockets,  or FurTURDada but he was right about the ChiComs.
#
# Also, Tesla needs… https://t.co/DFQGLDsoxq
# RT @CanYamanMalta_: I miss Tesla so much too 🤧❤
# #NetflixBayYanlış
# #BayYanlışOnLine https://t.co/9uc9dykbt6
# When Tesla went crazy with photography and graphic design. Love it, lol.
#
# https://t.co/5HCqr04656
#
#
# Negative tweets:
# RT @Auto_Porn: Retweet if you'd whip a matte black Tesla Cybertruck
# cc: @elonmusk https://t.co/lhQZ2sMvsU
# Positive tweets percentage: 55.55555555555556 %
# Negative tweets percentage: 22.22222222222222 %
# Neutral tweets percentage: 22.22222222222222 %
#
#
# Positive tweets:
# @MedicalFisher @TheRealLifeTiny @ElonsWorld Ditto. Super close to paying cash for a LR M3 fall of 2019. Put it all… https://t.co/tdCLqDsh8p
# thanks! $tsla $eth #ethereum  $btc  https://t.co/7OZQqKjPPE
# Thanks for the $1k
# DISCORD https://t.co/WF4QyzDqtc
#
#  Best stock trade Group out there! $AMZN $AMD $SPY $QQQ $ATH… https://t.co/kCqROVOr1D
# RT @FredericLambert: Can we take a moment to appreciate that right now there's a sex and weed joke on the front page of the world's most va…
# thanks! $tsla $eth #ethereum  $btc  https://t.co/U5Xp8HdEw9
#
#
# Negative tweets:
# RT @JasameSmith: I would rather be RIGHT than RICH, you #tsla IDIOTS!!!!! #tslaq https://t.co/YniFPUPdx0
# @TLPrivate_ @RayTL_ How long before earnings will you wait before you decide whether or not to hold through earning… https://t.co/tzLdjoQ7aw
# Positive tweets percentage: 37.5 %
# Negative tweets percentage: 37.5 %
# Neutral tweets percentage: 25.0 %
#
#
# Positive tweets:
# @hockeyguy199 @MurrayPolisky @ScottWiper @GMCcanada Ah ok, pic I saw was just a Tahoe with a new grill.  And that a… https://t.co/aKoaT5hR1Z
# RT @Teslarati: Tesla Model 3 shows that it’s at home on the track in Japan’s all-EV Grand Prix
# https://t.co/XfHGvZsrFb
# It should be noted that VBM for Polk County in 2016, Trump soundly defeated Clinton 56%-41% (77k total votes). With… https://t.co/M96U7MP5b1
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @shipt_shopper: Update:  After two weeks on Shipt's new pay scale, I'm down $187. I'm making about $3 less per hour of work.
#
# https://t…
# @DuckinHell The interwebs can be used to search a model 3 gets 250 miles per charge and starts at $35k; the long ra… https://t.co/xraTwJQcWb
# Positive tweets percentage: 11.11111111111111 %
# Negative tweets percentage: 22.22222222222222 %
# Neutral tweets percentage: 66.66666666666667 %
#
#
# Positive tweets:
# Tesla Model S 2016+ owners only. (and maybe Model X). Trying to understand if this is a real issue, statistically s… https://t.co/VUNh7UMO40
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @Starkiller786: @elonmusk @Tesla The craftsmanship of your cars are terrible. The model X I paid 130k for has had a nonfunctional window…
# Positive tweets percentage: 62.5 %
# Negative tweets percentage: 25.0 %
# Neutral tweets percentage: 12.5 %
#
#
# Positive tweets:
# RT @FredericLambert: Can we take a moment to appreciate that right now there's a sex and weed joke on the front page of the world's most va…
# @elonmusk i heard you made the model s $69,420.  Thats hilarious!!! Make the @Tesla model Y $80,085!
# RT @easyyachts: New Yachts: Princess Yachts Y78: The Princess Yachts Y78-the smallest in the British builder's three-model Y series-introdu…
# New Yachts: Princess Yachts Y78: The Princess Yachts Y78-the smallest in the British builder's three-model Y series… https://t.co/1MO5izK8Uq
# RT @BLKMDL3: My @Tesmanian_com mats for Model Y 2nd row seatbacks coming tomorrow! Thanks @vincent13031925!!!
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @MotorTrend: We put the 2020 @Tesla Model Y Long Range electric SUV on our test track to find out what it can do—and it turns out, well,…
# Positive tweets percentage: 50.0 %
# Negative tweets percentage: 20.0 %
# Neutral tweets percentage: 30.0 %
#
#
# Positive tweets:
# @AZGeoDude Not that we're aware of, but we'd love to help! What exactly are you experiencing? Which device (make an… https://t.co/zowoGqqHrm
# .@Flipgrid kindly gave me some props for being one of the people to suggest this, BUT it's NOT me.
# This is the mod… https://t.co/PzW6TixPso
# RT @xairylle_art: "Idk, Katsuki. It does sound like you rescued this bird."
#
# "Right? Right!?"
#
# "For the last time, I did NOT rescue this bi…
# RT @timacdonald87: ✍️ Using @laravelphp's Policies and Route Model Binding *without* Eloquent
#
# A fun little adventure I went on this week a…
# RT @KylieJayneArt: Had the awesome opportunity to create Obsidian Dragon Sett's in game 3D model for League of Legends. ♥️ Concept by Rheek…
#
#
# Negative tweets:
# RT @JamesSACorey: It's bad for the shows.  You spend all year making a show and it gets into the public consciousness for a week and then d…
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# Positive tweets percentage: 37.5 %
# Negative tweets percentage: 37.5 %
# Neutral tweets percentage: 25.0 %
#
#
# Positive tweets:
# @hockeyguy199 @MurrayPolisky @ScottWiper @GMCcanada Ah ok, pic I saw was just a Tahoe with a new grill.  And that a… https://t.co/aKoaT5hR1Z
# RT @Teslarati: Tesla Model 3 shows that it’s at home on the track in Japan’s all-EV Grand Prix
# https://t.co/XfHGvZsrFb
# It should be noted that VBM for Polk County in 2016, Trump soundly defeated Clinton 56%-41% (77k total votes). With… https://t.co/M96U7MP5b1
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @shipt_shopper: Update:  After two weeks on Shipt's new pay scale, I'm down $187. I'm making about $3 less per hour of work.
#
# https://t…
# @DuckinHell The interwebs can be used to search a model 3 gets 250 miles per charge and starts at $35k; the long ra… https://t.co/xraTwJQcWb
# Positive tweets percentage: 11.11111111111111 %
# Negative tweets percentage: 22.22222222222222 %
# Neutral tweets percentage: 66.66666666666667 %
#
#
# Positive tweets:
# Tesla Model S 2016+ owners only. (and maybe Model X). Trying to understand if this is a real issue, statistically s… https://t.co/VUNh7UMO40
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @Starkiller786: @elonmusk @Tesla The craftsmanship of your cars are terrible. The model X I paid 130k for has had a nonfunctional window…
# Positive tweets percentage: 62.5 %
# Negative tweets percentage: 25.0 %
# Neutral tweets percentage: 12.5 %
#
#
# Positive tweets:
# RT @FredericLambert: Can we take a moment to appreciate that right now there's a sex and weed joke on the front page of the world's most va…
# @elonmusk i heard you made the model s $69,420.  Thats hilarious!!! Make the @Tesla model Y $80,085!
# RT @easyyachts: New Yachts: Princess Yachts Y78: The Princess Yachts Y78-the smallest in the British builder's three-model Y series-introdu…
# New Yachts: Princess Yachts Y78: The Princess Yachts Y78-the smallest in the British builder's three-model Y series… https://t.co/1MO5izK8Uq
# RT @BLKMDL3: My @Tesmanian_com mats for Model Y 2nd row seatbacks coming tomorrow! Thanks @vincent13031925!!!
#
#
# Negative tweets:
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq
# RT @MotorTrend: We put the 2020 @Tesla Model Y Long Range electric SUV on our test track to find out what it can do—and it turns out, well,…
# Positive tweets percentage: 50.0 %
# Negative tweets percentage: 20.0 %
# Neutral tweets percentage: 30.0 %
#
#
# Positive tweets:
# @AZGeoDude Not that we're aware of, but we'd love to help! What exactly are you experiencing? Which device (make an… https://t.co/zowoGqqHrm
# .@Flipgrid kindly gave me some props for being one of the people to suggest this, BUT it's NOT me.
# This is the mod… https://t.co/PzW6TixPso
# RT @xairylle_art: "Idk, Katsuki. It does sound like you rescued this bird."
#
# "Right? Right!?"
#
# "For the last time, I did NOT rescue this bi…
# RT @timacdonald87: ✍️ Using @laravelphp's Policies and Route Model Binding *without* Eloquent
#
# A fun little adventure I went on this week a…
# RT @KylieJayneArt: Had the awesome opportunity to create Obsidian Dragon Sett's in game 3D model for League of Legends. ♥️ Concept by Rheek…
#
#
# Negative tweets:
# RT @JamesSACorey: It's bad for the shows.  You spend all year making a show and it gets into the public consciousness for a week and then d…
# @realdanlyons @greeneatz Your math sucks. Model 3 costs 35K, Model Y about 45K,  S &amp; X  about 70k. So who knows wha… https://t.co/AuOz0aXaGq

# %% [markdown]
# ### Exxon

# %%
if __name__ == "__main__": 
    # calling main function 
    main(['Exxon Mobil'.casefold()])
    main(['ExxonMobil'.casefold()])
    main(['Exxon'.casefold()])
    main(['XOM'.casefold()])
# Out:
# Positive tweets percentage: 25.0 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 75.0 %
#
#
# Positive tweets:
# Exxon Mobil Corp. (XOM) surprised the market with Q4 result. Credit Suisse changed the rating to Hold, as Exxon Mob… https://t.co/bNDQstZdLv
# Thuesday #NYSE Top 100 Volume Leaders
# #GeneralElectric ( $GE) Sell
# #BankofAmerica Corp ( $BAC) ---
# #Fastly Inc. (… https://t.co/EPaBQfmXPZ
#
#
# Negative tweets:
# Positive tweets percentage: 10.0 %
# Negative tweets percentage: 10.0 %
# Neutral tweets percentage: 80.0 %
#
#
# Positive tweets:
# Guyana Pompeo's manipulated vote
# Who WINS
# Exxonmobil WINS
# Jewish Rothschild's created the Soviet Union own Russia,… https://t.co/zNzFrAAOur
#
#
# Negative tweets:
# .@exxonmobil forms research venture w/ POSCO 👉https://t.co/e7thNPK5Fi
#
# POSCO is a key partner of #Myanmar military,… https://t.co/d6NpW2JBAC
# Positive tweets percentage: 30.0 %
# Negative tweets percentage: 40.0 %
# Neutral tweets percentage: 30.0 %
#
#
# Positive tweets:
# I was in the gas station earlier and this guy farted and he really said “well that’s gonna itch when it dries” my m… https://t.co/kQhiFXnLeX
# @Noahpinion Old enough to live through the time when the two most valuable companies in the world by market cap were Exxon and Cisco.
# @007Rukdme @MollyJongFast The cooperation has not ceased - Trump put Tillerson at State (friendly to Putin because… https://t.co/aqwUSD6UaI
#
#
# Negative tweets:
# RT @Cakess____: Shoot up towards Claiborne make a left cut through Exxon now I’m on willow street the spot where the killed be i misss the…
# Shoot up towards Claiborne make a left cut through Exxon now I’m on willow street the spot where the killed be i mi… https://t.co/Jyc7RL6KQt
# I realize that boycotting exxon would have little to no effect. Vote to regulate CO2 emissions. Make a carbon tax.
# @FakeDanUggla I was at a random exxon station driving back to ga from working in new York over the summer. Just yel… https://t.co/13zVOM1TlS
# Positive tweets percentage: 40.0 %
# Negative tweets percentage: 0.0 %
# Neutral tweets percentage: 60.0 %
#
#
# Positive tweets:
# Crude Oil Stalls in Resistance Zone…This may become a very good trading signal in the next few days or weeks ahead… https://t.co/zzEaE92ZVB
# Wow! Real-time stocks chat and live alerts👌👌
# https://t.co/5JpLtI1XVJ
#
# $SPY $QQQ $AMZN $NVDA $BA $TSLA $BABA $AMD… https://t.co/nGWwnvPt53
# $NEE - Exxon Vs. NextEra Energy: The Real King Of Energy. https://t.co/szJbDp8Cd4  Great Dividend Stocks BUY NEE and XOM !
# 📈💰Really awesome place for stocks, options, day &amp; swing trading:👇🏾
#
# https://t.co/YF89unpajn
#
# $AMZN $NVDA $BA $TSLA… https://t.co/8zoA12fq8n
#
#
# Negative tweets:
