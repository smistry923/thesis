# %%
# Install yfinance package. 
# !pip install yfinance 
import yfinance as yf   
import matplotlib.pyplot as plt

# %% [markdown]
# ## Volkswagen

# %%
data = yf.download('VOW3.DE','2015-09-01','2015-10-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('VOW3.DE','2015-09-01','2015-11-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('VOW3.DE','2015-09-01','2015-12-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('VOW3.DE','2015-09-01','2020-01-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Wells Fargo

# %%
data = yf.download('WFC','2016-09-01','2016-10-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('WFC','2016-09-01','2016-11-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('WFC','2016-09-01','2016-12-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('WFC','2016-09-01','2020-01-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Equifax

# %%
data = yf.download('EFX','2017-09-01','2017-10-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('EFX','2017-09-01','2017-11-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('EFX','2017-09-01','2017-12-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = yf.download('EFX','2017-09-01','2020-01-01') 
data.Close.plot() 
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
